# %% [markdown]
# # Chapter 2 Assignment

# %% [markdown]
# ## Luke Hicks

# %%
import pandas as pd

# %%
ramen = pd.read_csv('ramen-ratings.csv')

# %%
ramen.head()
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#   Country  Stars
# 0   Japan   3.75
# 1  Taiwan   1.00
# 2     USA   2.25
# 3  Taiwan   2.75
# 4   India   3.75

# %%
ramen.tail()
# Out:
#          Brand                                            Variety Style  \
# 2572     Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2573   Wai Wai                     Oriental Style Instant Noodles  Pack
# 2574   Wai Wai                                     Tom Yum Shrimp  Pack
# 2575   Wai Wai                               Tom Yum Chili Flavor  Pack
# 2576  Westbrae                                         Miso Ramen  Pack
#
#        Country  Stars
# 2572   Vietnam    3.5
# 2573  Thailand    1.0
# 2574  Thailand    2.0
# 2575  Thailand    2.0
# 2576       USA    0.5

# %%
ramen.describe()
# Out:
#              Stars
# count  2577.000000
# mean      3.654676
# std       1.015331
# min       0.000000
# 25%       3.250000
# 50%       3.750000
# 75%       4.250000
# max       5.000000

# %%
ramen.nunique()
# Out:
# Brand       355
# Variety    2410
# Style         7
# Country      38
# Stars        42
# dtype: int64

# %%
vietnam = ramen[ramen['Country'] == 'Vietnam']
vietnam
# Out:
#               Brand                                            Variety Style  \
# 18         Binh Tay                                         Mi Hai Cua  Pack
# 52    Uni-President                                    Mushroom Flavor  Pack
# 143        Mum Ngon                                   Lau Tom Chua Cay  Pack
# 224           Vifon  Viet Cuisine Bun Rieu Cua Sour Crab Soup Insta...  Bowl
# 365         Acecook                             Oh! Ricey Pork Flavour  Pack
# ...             ...                                                ...   ...
# 2486       Binh Tay                                   Mi Chay Mushroom  Pack
# 2535        Ve Wong                             Kung-Fu Chicken Flavor  Pack
# 2570        Ve Wong                                      Mushroom Pork  Pack
# 2571          Vifon                                           Nam Vang  Pack
# 2572          Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
#
#       Country  Stars
# 18    Vietnam   4.00
# ...

# %%
brand_style = ramen[['Brand', 'Style']]
brand_style
# Out:
#                Brand Style
# 0          New Touch   Cup
# 1           Just Way  Pack
# 2             Nissin   Cup
# 3            Wei Lih  Pack
# 4     Ching's Secret  Pack
# ...              ...   ...
# 2572           Vifon  Bowl
# 2573         Wai Wai  Pack
# 2574         Wai Wai  Pack
# 2575         Wai Wai  Pack
# 2576        Westbrae  Pack
#
# [2577 rows x 2 columns]

# %%
country = ramen['Country']
country
# Out:
# 0          Japan
# 1         Taiwan
# 2            USA
# 3         Taiwan
# 4          India
#           ...
# 2572     Vietnam
# 2573    Thailand
# 2574    Thailand
# 2575    Thailand
# 2576         USA
# Name: Country, Length: 2577, dtype: object

# %%
sort = ramen.sort_values(by='Stars', ascending=False)
sort
# Out:
#                Brand                                            Variety Style  \
# 1585     Prima Taste                            Singapore Laksa La Mian  Pack
# 446         Maruchan  Instant Lunch Chipotle Chicken Flavor Ramen No...   Cup
# 484         Nongshim          Champong Noodle Soup Spicy Seafood Flavor  Pack
# 483           Nissin                              Straits Kitchen Laksa  Pack
# 1613          Nissin                 Raoh Backfat Rich Soy Sauce Flavor  Bowl
# ...              ...                                                ...   ...
# 522             Koyo                 Garlic Pepper Reduced Sodium Ramen  Pack
# 561    Samyang Foods                            Honey & Cheese Big Bowl  Bowl
# 950            Azami                                Kimchee Noodle Soup   Cup
# 2079  Hsin Tung Yang                     Tiny Noodle With Oyster Flavor  Pack
# 52     Uni-President                                    Mushroom Flavor  Pack
#
#           Country  Stars
# ...

# %%
ramen['Country'] = ramen['Country'].replace('USA', 'United States')

# %%
ramen.to_csv('ramen-ratings-updated.csv', index=False)
ramen.head()
# Out:
#             Brand                                            Variety Style  \
# 0       New Touch                          T's Restaurant Tantanmen    Cup
# 1        Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2          Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3         Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4  Ching's Secret                                    Singapore Curry  Pack
#
#          Country  Stars
# 0          Japan   3.75
# 1         Taiwan   1.00
# 2  United States   2.25
# 3         Taiwan   2.75
# 4          India   3.75

# %%
countries = ramen['Country'].nunique()
countries
# Out:
# 37

# %%
average = ramen.groupby('Country')['Stars'].mean()

top_three_countries = average.sort_values(ascending=False).head(3)
top_three_countries
# Out:
# Country
# Brazil      4.350000
# Sarawak     4.333333
# Cambodia    4.200000
# Name: Stars, dtype: float64

# %%
average = ramen.groupby('Country')['Stars'].mean()

bottom_three_countries = average.sort_values(ascending=True).head(3)
bottom_three_countries
# Out:
# Country
# Nigeria        1.500000
# Canada         2.243902
# Netherlands    2.483333
# Name: Stars, dtype: float64

# %%
# %%time

import time

average = ramen.groupby('Country')['Stars'].mean()

bottom_three_countries = average.sort_values(ascending=True).head(3)
bottom_three_countries
# Out:
# CPU times: total: 0 ns
# Wall time: 2 ms
# Country
# Nigeria        1.500000
# Canada         2.243902
# Netherlands    2.483333
# Name: Stars, dtype: float64
